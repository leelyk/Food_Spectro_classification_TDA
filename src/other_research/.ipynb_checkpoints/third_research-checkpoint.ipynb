# %%
import numpy as np

import pandas as pd

from gtda.time_series import SingleTakensEmbedding

from gtda.plotting import plot_point_cloud

from persim import plot_diagrams 

from ripser import ripser

import matplotlib.pyplot as plt

import itertools

# %%
def takens_embedding_test(signal, embedding_dimension):
    
    embedder = SingleTakensEmbedding(parameters_type = "fixed", dimension = embedding_dimension)
    
    point_cloud = embedder.fit_transform(signal)
    
    return point_cloud

def persistent_homology_test(point_cloud):
    
    persistent_diagram = ripser(point_cloud)['dgms']
    
    return persistent_diagram 

np.random.seed(42)

a = np.random.randint(1, 20, 20)

print('first array：', a)

b = a[::-1]

print('second array：', b)

aa = takens_embedding_test(a, embedding_dimension = 2)

bb = takens_embedding_test(b, embedding_dimension = 2)

plt.figure(figsize = (6, 6))

plt.scatter(aa[:, 0], aa[:, 1], color = 'steelblue', marker = 'o', facecolors = 'none', label = 'data1', s = 100)

# get x-axis and y-axis limits

xmin, xmax, ymin, ymax = plt.axis()

plt.plot([xmin, xmax], [ymin, ymax], color ='grey', linestyle='--') 

plt.legend()

# plt.show()

# plt.figure(figsize=(6, 6))

plt.scatter(bb[:, 0], bb[:, 1], color = 'tomato', marker = '+', label = 'data2' , s = 100)

plt.plot([xmin, xmax], [ymin, ymax], color = 'grey', linestyle = '--') 

plt.legend()

plt.savefig('../../images/2_arrays_point_cloud.png')

plt.show()
# Out:
# first array： [ 7 15 11  8  7 19 11 11  4  8  3  2 12  6  2  1 12 12 17 10]
# second array： [10 17 12 12  1  2  6 12  2  3  8  4 11 11 19  7  8 11 15  7]

# %%
aaa = persistent_homology_test(aa)

bbb = persistent_homology_test(bb)

plt.figure(figsize = (6, 6))

x = np.linspace(-1, 9, 100)

plt.plot(x, x, 'k--', label = r'$\infty$')  

#import matplotlib as mpl
#mpl.rcParams.update(mpl.rcParamsDefault)
#plt.rcParams["text.latex.preamble"].join([
#        r"\usepackage{dashbox}",              
#        r"\setmainfont{xcolor}",
#])

data1_h0 = r'$\mathrm{data1 } \, H_{0}$'

data1_h1 = r'$\mathrm{data1 } \, H_{1}$'

marker1 = 'o'

size1 = 100

plt.scatter(aaa[0][:, 0], aaa[0][:, 1], color = 'steelblue', marker = marker1, facecolors = 'none', label = data1_h0, s = size1)

plt.scatter(0, 8.5, color = 'steelblue', marker = marker1, facecolors = 'none', s = size1)

plt.scatter(aaa[1][:, 0], aaa[1][:, 1], color = 'tomato', marker = marker1, facecolors = 'none', label = data1_h1, s = size1)

data2_h0 = r'$\mathrm{data2 } \, H_{0}$'

data2_h1 = r'$\mathrm{data2 } \, H_{1}$'

marker2 = '+'

size2 = 100

plt.scatter(bbb[0][:, 0], bbb[0][:, 1], color = 'steelblue', marker = marker2, label = data2_h0, s = size2)

plt.scatter(0, 8.5, color = 'steelblue', marker = marker2, s = size2)

plt.scatter(bbb[1][:, 0], bbb[1][:, 1], color = 'tomato', marker = marker2, label = data2_h1, s = size2)

plt.axhline(y = 8.5, color = 'k', linestyle = '--') 

plt.legend(loc = 'lower right')

plt.xlabel('Birth')

plt.ylabel('Death')

plt.xlim(-1, 9)

plt.ylim(-1, 9)

plt.savefig('../../images/2_arrays_persistence_diagram.png')

plt.show()
